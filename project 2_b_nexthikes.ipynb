# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df3=pd.read_csv("merged_data1.csv")

# %%
df3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  2011-01-01       1   0     1   0    False        6           1
# 1          2  2011-01-01       1   0     1   1    False        6           1
# 2          3  2011-01-01       1   0     1   2    False        6           1
# 3          4  2011-01-01       1   0     1   3    False        6           1
# 4          5  2011-01-01       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606         NaN       1   0     1  11    False        5           3
# 606      607         NaN       1   0     1  12    False        5           3
# 607      608         NaN       1   0     1  13    False        5           3
# 608      609         NaN       1   0     1  14    False        5           3
# 609      610         NaN       1   0     1  15    False        5           2
#
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      277 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
#  10  Unnamed: 0  610 non-null    int64
#  11  atemp       610 non-null    float64
#  12  hum         610 non-null    float64
#  13  windspeed   610 non-null    float64
#  14  casual      610 non-null    int64
#  15  registered  610 non-null    int64
#  16  cnt         610 non-null    int64
# dtypes: bool(1), float64(4), int64(11), object(1)
# memory usage: 77.0+ KB

# %%
df3["dteday"]=pd.to_datetime(df3["dteday"],errors="coerce")

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      277 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
#  10  Unnamed: 0  610 non-null    int64
#  11  atemp       610 non-null    float64
#  12  hum         610 non-null    float64
#  13  windspeed   610 non-null    float64
#  14  casual      610 non-null    int64
#  15  registered  610 non-null    int64
#  16  cnt         610 non-null    int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(11)
# memory usage: 77.0 KB

# %%
df3.isnull().sum()
# Out:
# instant         0
# dteday        333
# season          0
# yr              0
# mnth            0
# hr              0
# holiday         0
# weekday         0
# weathersit      0
# temp            0
# Unnamed: 0      0
# atemp           0
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# dtype: int64

# %%
df3["dteday"].value_counts()
# Out:
# dteday
# 2011-01-01    24
# 2011-08-01    24
# 2011-09-01    24
# 2011-10-01    24
# 2011-02-01    23
# 2011-04-01    23
# 2011-05-01    23
# 2011-06-01    23
# 2011-07-01    23
# 2011-03-01    22
# 2011-11-01    22
# 2011-12-01    22
# Name: count, dtype: int64

# %%
df3["dteday"].fillna(df3["dteday"].median(),inplace=True)

# %%
df3.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# Unnamed: 0    0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df3.nunique()
# Out:
# instant       610
# dteday         12
# season          1
# yr              1
# mnth            1
# hr             24
# holiday         2
# weekday         7
# weathersit      4
# temp           23
# Unnamed: 0    610
# atemp          29
# hum            61
# windspeed      20
# casual         32
# registered    150
# cnt           165
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# Unnamed: 0    0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df3.describe().round(2)
# Out:
#        instant                         dteday  season     yr   mnth      hr  \
# count   610.00                            610   610.0  610.0  610.0  610.00
# mean    305.50  2011-06-24 04:38:33.442622976     1.0    0.0    1.0   11.80
# min       1.00            2011-01-01 00:00:00     1.0    0.0    1.0    0.00
# 25%     153.25            2011-07-01 00:00:00     1.0    0.0    1.0    6.00
# 50%     305.50            2011-07-01 00:00:00     1.0    0.0    1.0   12.00
# 75%     457.75            2011-07-01 00:00:00     1.0    0.0    1.0   18.00
# max     610.00            2011-12-01 00:00:00     1.0    0.0    1.0   23.00
# std     176.24                            NaN     0.0    0.0    0.0    6.85
#
#        weekday  weathersit    temp  Unnamed: 0   atemp     hum  windspeed  \
# count   610.00      610.00  610.00      610.00  610.00  610.00     610.00
# mean      2.98        1.48    0.20      304.50    0.20    0.56       0.20
# ...

# %%
df3.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# Unnamed: 0    0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
fig,ax=plt.subplots(figsize=(12,6))
sns.boxplot(ax=ax , x=df3["hr"],y=df3["cnt"])
ax.set_title("Bike rentals by the hour of the day")
ax.set_xlabel("Hour")
ax.set_ylabel("Total Rentals")
plt.show()

# %% [markdown]
# ## Above graph interprets that bike rental increased around
# ##  (7 AM-9 AM) and evening around (5 PM-7 PM)

# %%
df4=pd.read_csv("dataset_3 - dataset_3.csv")

# %%
df4
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    object
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), float64(4), int64(10), object(1)
# memory usage: 46.2+ KB

# %%
df4["dteday"]=pd.to_datetime(df4["dteday"],errors="coerce")

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    datetime64[ns]
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(10)
# memory usage: 46.2 KB

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="mnth",y="cnt",data=df4)
plt.title("Bike rentals by month")
plt.xlabel("Month")
plt.ylabel("Total Rentals")
plt.show()

# %% [markdown]
# ## The above boxplot shows variation in bike rentals across different months(May)

# %%
plt.figure(figsize=(8,5))
sns.regplot(data=df4, x="windspeed",y="cnt",scatter_kws={"alpha": 0.5,"color": "orange"},line_kws={"color": "red"})
plt.title("Effect of wind speed on Bike Rentals")
plt.xlabel("Wind speed(Normalized)")
plt.ylabel("Total Bike Rentals")
plt.show()

# %% [markdown]
# ##  The regression line shows a slight positive correlation between wind speed and bike rentals
# ##  as wind speed increases, bike rentals increase slightly,but not a strong effect
# ##  other factors likely to play a more significant role in
# ##  rental demand like weather conditions,days of the week,time of the day etc.

# %%
merged_df2=pd.concat([df3,df4],ignore_index=True,join="inner")

# %%
merged_df2.to_csv("merged_dta2.csv",index=False)

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x=merged_df2["temp"],y=merged_df2["cnt"],alpha=0.5,color="blue")
plt.xlabel("Temperature")
plt.ylabel("Total Rentals")
plt.title("Impact of temperature on bike rentals")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=merged_df2["season"],y=merged_df2["cnt"])
plt.xlabel("season(1: Spring, 2: Summer ,3: Fall ,4: Winter)")
plt.ylabel("Total rentals(cnt)")
plt.title("Total bike rentals by season")
plt.show()

# %% [markdown]
# ## Above graph shows that summer had highest bike rentals

# %% [markdown]
# ## Higher temperature leads to more bike rentals
# ## People prefer bike rentals when weather is clear ,warm
# ## Temperature strongly influence rentals

# %%
plt.figure(figsize=(8,5))
sns.histplot(merged_df2["cnt"],bins=30,kde=True,color="blue")
plt.xlabel("Total rentals(cnt)")
plt.ylabel("Frequency")
plt.title("Distribution of bike rentals")
# Out:
# Text(0.5, 1.0, 'Distribution of bike rentals')

# %%
plt.figure(figsize=(8,5))
merged_df2.groupby("dteday")["cnt"].sum().plot(color="green",linewidth=2)
plt.xlabel("Date")
plt.ylabel("Total rentals(cnt)")
plt.xticks(rotation=45)
plt.title("Bike rentals over time")
# Out:
# Text(0.5, 1.0, 'Bike rentals over time')

# %% [markdown]
# ## Higher rentals in warm months
# ## lower rentals in cold months
# ## Sudden spike indicates might be holiday,event lead to high demand
# ## Sudden decrease may be due to weather conditions or competition

# %%
season_rentals=merged_df2.groupby("season")[["casual","registered"]].sum()
plt.figure(figsize=(10,6))
season_rentals.plot(kind="bar",stacked=True,colormap="coolwarm",edgecolor="black",alpha=0.8,figsize=(10,6))
plt.xlabel("season")
plt.ylabel("Total rentals")
plt.title("Casual vs Registered bike rentals by season")
plt.legend(title="user Type")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## Warmer months (sring & summer )drive higher demand for both casual and registered ##user
# ##  casual riders are more sensitive to weather changes,while registered users remain stable ##  year round
# ##    winter has lowest rentals,as bikibg conditions become less favourable

# %%
merged_df2
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 995      615 2011-01-28       1   0     1  20    False        5           2
# 996      616 2011-01-28       1   0     1  21    False        5           2
# 997      617 2011-01-28       1   0     1  22    False        5           1
# 998      618 2011-01-28       1   0     1  23    False        5           1
# 999      619 2011-01-29       1   0     1   0    False        6           1
#
# ...

# %%
plt.figure(figsize=(10,5))
hourly_rentals=merged_df2.groupby("hr")[["cnt","casual","registered"]].mean()
plt.plot(hourly_rentals.index,hourly_rentals["cnt"],linestyle="--",color="blue",label="Total rentals")
plt.plot(hourly_rentals.index,hourly_rentals["casual"],linestyle="--",color="red",label="Casual users")
plt.plot(hourly_rentals.index,hourly_rentals["registered"],linestyle="--",color="green",label="Registered Users")
plt.xlabel("Hour of the day")
plt.ylabel("Average bike rentals")
plt.title("Hourly trend of bike rentals")
plt.xticks(range(0,24))
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## There are two major spikes in bike rentals:
# ##  Morning peak(around 8 AM):due to commuters travelling to school or office
# ##    Evening Peak (around5-7 PM):due to people returning home from office
# ##    Rentals reman low during midday and late night
# ##    registered users are increasing in morning and evening
# ##    Casual riders are higher in the afternoon (10 AM -6PM),suggesting more leisure riders.
# ##    Rentals drop significantly after 9 PM, likely due to fewer people riding bikes late at night

# %%
merged_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     1000 non-null   int64
#  1   dteday      1000 non-null   datetime64[ns]
#  2   season      1000 non-null   int64
#  3   yr          1000 non-null   int64
#  4   mnth        1000 non-null   int64
#  5   hr          1000 non-null   int64
#  6   holiday     1000 non-null   bool
#  7   weekday     1000 non-null   int64
#  8   weathersit  1000 non-null   int64
#  9   temp        1000 non-null   float64
#  10  atemp       1000 non-null   float64
#  11  hum         1000 non-null   float64
#  12  windspeed   1000 non-null   float64
#  13  casual      1000 non-null   int64
#  14  registered  1000 non-null   int64
#  15  cnt         1000 non-null   int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(10)
# memory usage: 118.3 KB

# %%
merged_df2.shape
# Out:
# (1000, 16)

# %%
merged_df2.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
new_mergeddf=merged_df2.reset_index(drop=True)

# %%
final_df = merged_df2.drop(columns=["Unnamed: 0"],errors="ignore")

# %%
final_df
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 995      615 2011-01-28       1   0     1  20    False        5           2
# 996      616 2011-01-28       1   0     1  21    False        5           2
# 997      617 2011-01-28       1   0     1  22    False        5           1
# 998      618 2011-01-28       1   0     1  23    False        5           1
# 999      619 2011-01-29       1   0     1   0    False        6           1
#
# ...

# %%
final_df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
final_df.describe().round(2)
# Out:
#        instant                      dteday  season      yr     mnth       hr  \
# count  1000.00                        1000  1000.0  1000.0  1000.00  1000.00
# mean    500.50  2011-05-01 02:22:33.600000     1.0     0.0     1.31    11.75
# min       1.00         2011-01-01 00:00:00     1.0     0.0     1.00     0.00
# 25%     250.75         2011-02-06 00:00:00     1.0     0.0     1.00     6.00
# 50%     500.50         2011-05-01 00:00:00     1.0     0.0     1.00    12.00
# 75%     750.25         2011-07-01 00:00:00     1.0     0.0     2.00    18.00
# max    1000.00         2011-12-01 00:00:00     1.0     0.0     2.00    23.00
# std     288.82                         NaN     0.0     0.0     0.46     6.90
#
#        weekday  weathersit     temp    atemp      hum  windspeed   casual  \
# count  1000.00     1000.00  1000.00  1000.00  1000.00    1000.00  1000.00
# mean      2.98        1.48     0.21     0.21     0.58       0.19     4.92
# ...

# %%
num_duplicates=final_df.duplicated().sum()
print(f"total duplicate rows:{num_duplicates}")
# Out:
# total duplicate rows:0

# %%
duplicates=final_df[final_df.duplicated()]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     1000 non-null   int64
#  1   dteday      1000 non-null   datetime64[ns]
#  2   season      1000 non-null   int64
#  3   yr          1000 non-null   int64
#  4   mnth        1000 non-null   int64
#  5   hr          1000 non-null   int64
#  6   holiday     1000 non-null   bool
#  7   weekday     1000 non-null   int64
#  8   weathersit  1000 non-null   int64
#  9   temp        1000 non-null   float64
#  10  atemp       1000 non-null   float64
#  11  hum         1000 non-null   float64
#  12  windspeed   1000 non-null   float64
#  13  casual      1000 non-null   int64
#  14  registered  1000 non-null   int64
#  15  cnt         1000 non-null   int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(10)
# memory usage: 118.3 KB

# %%
final_df.nunique()
# Out:
# instant       1000
# dteday          29
# season           1
# yr               1
# mnth             2
# hr              24
# holiday          2
# weekday          7
# weathersit       4
# temp            23
# atemp           30
# hum             64
# windspeed       20
# casual          42
# registered     186
# cnt            191
# dtype: int64

# %%
numerical_cols=final_df.select_dtypes(include=[np.number])
Q1=numerical_cols.quantile(0.25)
Q3=numerical_cols.quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
outliers=(numerical_cols<lower_bound)|(numerical_cols>upper_bound)
outliers_value=numerical_cols[outliers]
print(outliers_value.stack())
outlier_counts=outliers.sum()
print(outlier_counts)
# Out:
# 10   temp       0.3800
# 11   casual    26.0000
# 12   temp       0.4200
#      atemp      0.4242
#      casual    29.0000
#                 ...
# 981  atemp      0.4091
# 982  temp       0.4000
#      atemp      0.4091
# 983  temp       0.3800
# 984  temp       0.3800
# Length: 253, dtype: float64
# instant        0
# season         0
# yr             0
# mnth           0
# hr             0
# weekday        0
# weathersit     1
# temp          66
# atemp         41
# hum            0
# windspeed      4
# casual        66
# registered    45
# cnt           30
# dtype: int64

# %% [markdown]
# ## From above we can seee that outliers lie in columns(temp,atemp,hum,windspeed,casual,registered,cnt )

# %% [markdown]
# ##  Based on that we ll handle the outliers one by one

# %%
plt.boxplot(final_df['temp'])
plt.show()

# %%
final_df['temp'].describe()
# Out:
# count    1000.000000
# mean        0.205900
# std         0.078977
# min         0.020000
# 25%         0.160000
# 50%         0.200000
# 75%         0.240000
# max         0.460000
# Name: temp, dtype: float64

# %%
final_df=final_df.dropna()

# %%
numeric_cols=final_df.select_dtypes(include=["number"]).columns.tolist()
print("Numerical Columns",numeric_cols)
# Out:
# Numerical Columns ['instant', 'season', 'yr', 'mnth', 'hr', 'weekday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']

# %%
Q1=0.16
Q3=0.24

# %%
upper_limit1=Q3+1.5*(Q3-Q1)
lower_limit1=Q3-1.5*(Q3-Q1)

# %%
upper_limit1
# Out:
# 0.36

# %%
lower_limit1
# Out:
# 0.12000000000000001

# %%
final_df['temp']= np.where(final_df['temp']>upper_limit1,final_df['temp'].mean(),final_df['temp'])

# %%
final_df['temp']= np.where(final_df['temp']<lower_limit1,final_df['temp'].mean(),final_df['temp'])

# %%
final_df["atemp"].describe()
# Out:
# count    1000.000000
# mean        0.211793
# std         0.076295
# min         0.000000
# 25%         0.166700
# 50%         0.212100
# 75%         0.257600
# max         0.454500
# Name: atemp, dtype: float64

# %%
Q1=0.1667
Q3=0.2576

# %%
upper_limit2=Q3+1.5*(Q3-Q1)
lower_limit2=Q3-1.5*(Q3-Q1)

# %%
upper_limit2
# Out:
# 0.39395

# %%
lower_limit2
# Out:
# 0.12124999999999997

# %%
plt.boxplot(final_df['atemp'])
plt.show()

# %%
final_df['atemp']= np.where(final_df['atemp']>upper_limit2,final_df['atemp'].mean(),final_df['atemp'])

# %%
final_df['atemp']= np.where(final_df['atemp']<lower_limit2,final_df['atemp'].mean(),final_df['atemp'])

# %%
plt.boxplot(final_df['casual'])
plt.show()

# %%
final_df["casual"].describe()
# Out:
# count    1000.000000
# mean        4.921000
# std         7.643899
# min         0.000000
# 25%         0.000000
# 50%         3.000000
# 75%         6.000000
# max        62.000000
# Name: casual, dtype: float64

# %%
Q1=0.00
Q3=6.00

# %%
upper_limit3=Q3+1.5*(Q3-Q1)
lower_limit3=Q3-1.5*(Q3-Q1)

# %%
upper_limit3
# Out:
# 15.0

# %%
lower_limit3
# Out:
# -3.0

# %%
final_df['casual']= np.where(final_df['casual']>upper_limit3,final_df['casual'].mean(),final_df['casual'])

# %%
plt.boxplot(final_df['registered'])
plt.show()

# %%
final_df["registered"].describe()
# Out:
# count    1000.000000
# mean       53.383000
# std        47.893968
# min         0.000000
# 25%        15.000000
# 50%        46.000000
# 75%        74.000000
# max       247.000000
# Name: registered, dtype: float64

# %%
Q1=15.0
Q3=74.0

# %%
upper_limit4=Q3+1.5*(Q3-Q1)
lower_limit4=Q3-1.5*(Q3-Q1)

# %%
upper_limit4
# Out:
# 162.5

# %%
lower_limit4
# Out:
# -14.5

# %%
final_df['registered']= np.where(final_df['registered']>upper_limit4,final_df['registered'].mean(),final_df['registered'])

# %%
plt.boxplot(final_df['cnt'])
plt.show()

# %%
final_df["cnt"].describe()
# Out:
# count    1000.000000
# mean       58.304000
# std        50.985558
# min         1.000000
# 25%        16.000000
# 50%        49.000000
# 75%        83.000000
# max       249.000000
# Name: cnt, dtype: float64

# %%
Q1=16.0
Q3=83.0

# %%
upper_limit5=Q3+1.5*(Q3-Q1)
lower_limit5=Q3-1.5*(Q3-Q1)

# %%
upper_limit5
# Out:
# 183.5

# %%
lower_limit5
# Out:
# -17.5

# %%
final_df['cnt']= np.where(final_df['cnt']>upper_limit5,final_df['cnt'].mean(),final_df['cnt'])

# %%
final_df
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 995      615 2011-01-28       1   0     1  20    False        5           2
# 996      616 2011-01-28       1   0     1  21    False        5           2
# 997      617 2011-01-28       1   0     1  22    False        5           1
# 998      618 2011-01-28       1   0     1  23    False        5           1
# 999      619 2011-01-29       1   0     1   0    False        6           1
#
# ...

# %%
numeric_df1=final_df.select_dtypes(include=["number"])

# %%
correlation_matrix=numeric_df1.corr()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(correlation_matrix,annot=True,cmap="coolwarm",fmt=".2f")
plt.title("Correlation matrix for final data")
plt.show()

# %%
## 1)Bike rentals highly corelated with registered (0.93) concluding that most rentals came from registered users 
     than casual users
    2)Moderate positive correlation with temp(0.25)and atemp(0.17)-means higher temperatured lead to more rentals.
   3)Slight negative correlation with humidity (-0.28)-concludes that humid weather affects bike rental negatively
    other notable corelations
    -temp(0.77) and atemp (0.77) are almost identical.
    higher humidity is associated with bad weather condition
     hour and cnt are also positivly corelated concluding that certain hours see higher rentals i.e morning and evening hours and 
     it decreases in afternoon.
     month has a very low corelation concluding that seasonal changes may not drastically impact temperature.
     weekday has a very low correlation-meaning there is no clear wekday/weekend pattern.

# %%
skewness_values=numeric_df1.skew()

# %%
print("skewness of numeric columns")
print(skewness_values)
# Out:
# skewness of numeric columns
# instant       0.000000
# season        0.000000
# yr            0.000000
# mnth          0.812772
# hr           -0.063524
# weekday       0.021925
# weathersit    1.044098
# temp          0.913386
# atemp         0.783981
# hum           0.436893
# windspeed     0.433675
# casual        1.177073
# registered    0.802588
# cnt           0.854777
# dtype: float64

# %%
for col in numeric_df1.columns:
    plt.figure(figsize=(6,4))
    sns.histplot(numeric_df1[col],kde=True,bins=30)
    plt.title(f"distibution of{col}(skewness:{numeric_df1[col].skew():.2f})")
    plt.show()

# %% [markdown]
# ###  1) Most rental counts are low,but there are some very high values.
# ###  2)Bike rentals are not eveny distributed showing sudden increase in rental  some days(possible
# ###      cause weekend,holidays or specific weather conditions).
# ###  3) Most values indicate good weather,with very few instances of extreme weather conditions.
# ###  4)Columns(temp ,atemp, hum, windspeed, mnth) are moderately right skewd indicating that occasional            ###       extreme   weather affects bike rentals .
# ###  5) Columns(hr, weekday, yr ) are evenly distributed making them more reliable for any prediction.

# %%
kurtosis_values=numeric_df1.kurt()

# %%
print("kurtosis of numeric columns")
print(kurtosis_values)
# Out:
# kurtosis of numeric columns
# instant      -1.200000
# season        0.000000
# yr            0.000000
# mnth         -1.342090
# hr           -1.169998
# weekday      -1.346819
# weathersit    0.034960
# temp          0.666360
# atemp         0.760861
# hum          -0.723123
# windspeed    -0.209853
# casual        0.937194
# registered    0.280263
# cnt           0.238756
# dtype: float64

# %%
for col in numeric_df1.columns:
    plt.figure(figsize=(6,4))
    sns.histplot(numeric_df1[col],kde=True,bins=30)
    plt.title(f"distibution of{col}(kurtosos:{numeric_df1[col].kurt():.2f})")
    plt.show()

# %% [markdown]
# ### 1) High Kurtosis: Columns(casual, registered,cnt) indicate that many days
# ###       with very few casual rentals but some days have very high rentals.
# ###      * registered column  indicating most rental counts are within normal range but some
# ###        extreme values exist (probably due to special events,weekends and holidays
#
# ###  2)Low Kurtosis: (columns-instant,mnth,hr,weekday,hum,windspeed)
# ###      *No specific month,hour,weekday dominate the datase.
# ###     *Rental demand does not concentrate ina single time frame but demand is different at different time.
#
# ###  3)Near Normal Kurtosis-Columns(weathersit, season, year) These variable does not have extreme values.
# ###     *Kurtosis of year suggests that both years (2011 and 2012) have balanced amount of data.
# ###     *this data set doesnot favour one year over the other.
# ###     *Different weather conditions appear in a balanced way.
# ###     *Rainy or stormy days are not excessively frequent compared to clear days.
# ###
